# %%
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [raw]
# ans = Matplotlib is a popular Python library used for creating static, animated, and interactive visualizations in various formats, such as charts, plots, graphs, and more. It provides a flexible and comprehensive framework for creating high-quality data visualizations for various purposes, including data exploration, analysis, and presentation. Matplotlib is widely used in data science, scientific research, engineering, and other fields to visualize data effectively.
#
# The `Pyplot` module of Matplotlib is a collection of functions that provide a convenient and MATLAB-like interface for creating basic plots and visualizations. Here are five common types of plots that can be created using the `Pyplot` module of Matplotlib:
#
# 1. **Line Plot**: Line plots are used to visualize data points connected by lines. They are suitable for displaying trends and patterns over a continuous range, such as time series data.
#
# 2. **Scatter Plot**: Scatter plots are used to visualize the relationship between two variables by displaying individual data points as dots on a two-dimensional plane. They help in identifying patterns, correlations, and outliers.
#
# 3. **Bar Plot**: Bar plots (or bar charts) are used to represent categorical data with rectangular bars. They are commonly used for comparing the values of different categories or showing frequency distributions.
#
# 4. **Histogram**: Histograms are used to visualize the distribution of a single numerical variable. They group data into bins or intervals and display the frequency or count of data points in each bin.
#
# 5. **Pie Chart**: Pie charts are used to represent the composition of a whole by dividing it into slices, where each slice represents a different category or component. They are useful for showing proportions or percentages.
#
# In addition to these, Matplotlib's `Pyplot` module can be used to create many other types of plots, including barh (horizontal bar) plots, box plots, violin plots, heatmaps, and more. It provides extensive customization options to control the appearance and style of plots, making it a versatile tool for data visualization in Python.

# %% [raw]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
# ans = A scatter plot is a type of data visualization that is used to display the relationship between two continuous variables. It is particularly useful for visualizing patterns, correlations, or clusters in the data. In a scatter plot, each data point is represented as a point on a two-dimensional plane, with one variable on the x-axis and another on the y-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create a scatter plot
plt.scatter(x, y)

# Add title, xlabel, and ylabel
plt.title('Scatter Plot of X vs. Y')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Show the plot
plt.show()

# %%
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#Use the following data:
#import numpy as np
#For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for four lines
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots in a 2x2 grid
plt.figure(figsize=(12, 8))

# Subplot 1
plt.subplot(2, 2, 1)
plt.plot(x1, y1, marker='o', color='b')
plt.title('Line Plot 1')

# Subplot 2
plt.subplot(2, 2, 2)
plt.plot(x2, y2, marker='s', color='g')
plt.title('Line Plot 2')

# Subplot 3
plt.subplot(2, 2, 3)
plt.plot(x3, y3, marker='^', color='r')
plt.title('Line Plot 3')

# Subplot 4
plt.subplot(2, 2, 4)
plt.plot(x4, y4, marker='d', color='purple')
plt.title('Line Plot 4')

# Adjust layout
plt.tight_layout()

# Show the figure with subplots
plt.show()

# %%
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#import numpy as np
#company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
#  ans = A bar plot, also known as a bar chart or bar graph, is a data visualization that represents categorical data with rectangular bars. Each bar's length or height is proportional to the value it represents, making it a useful tool for comparing the values of different categories or showing the distribution of a categorical variable. Bar plots are commonly used to display data that can be divided into distinct categories or groups.
#
# A horizontal bar plot is a variation of a bar plot where the bars are drawn horizontally, making it suitable for displaying data with long category labels or when you want to emphasize the comparison of values along the vertical axis.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='red')
plt.title('Bar Plot of Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Create a horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='green')
plt.title('Horizontal Bar Plot of Company Profits')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#box1 = np.random.normal(100, 10, 200)
#box2 = np.random.normal(90, 20, 200)

# %% [raw]
#  ans = A box plot, also known as a box-and-whisker plot, is a data visualization tool used to display the distribution and summary statistics of a dataset, particularly its central tendency, spread, and the presence of outliers. Box plots provide a graphical representation of the data's quartiles (including the median), minimum and maximum values, and potential outliers. They are useful for comparing the distribution of data between different groups or categories and for identifying skewness or extreme values in the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create a box plot
plt.figure(figsize=(8, 6))
plt.boxplot([box1, box2], labels=['Box 1', 'Box 2'], vert=False, patch_artist=True)
plt.title('Box Plot of Two Datasets')
plt.xlabel('Values')
plt.tight_layout()

# Show the plot
plt.show()
